# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Preprocessing

# %%
data = pd.read_csv('UCI_Credit_Card.csv')
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
def data_preprocessing(data):
  data.drop(['ID'], axis = 1, inplace = True)
  return data
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
data = pd.read_csv('UCI_Credit_Card.csv')
new_data = data_preprocessing(data)

# %%
new_data.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %%
X = new_data.drop(['default.payment.next.month'], axis = 1)
y = new_data['default.payment.next.month']

# %%
X
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    2          2         1   24      2      2     -1     -1
# 1       120000.0    2          2         2   26     -1      2      0      0
# 2        90000.0    2          2         2   34      0      0      0      0
# 3        50000.0    2          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# 29999    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %%
X.mean()
# Out:
# LIMIT_BAL    167484.322667
# SEX               1.603733
# EDUCATION         1.853133
# MARRIAGE          1.551867
# AGE              35.485500
# PAY_0            -0.016700
# PAY_2            -0.133767
# PAY_3            -0.166200
# PAY_4            -0.220667
# PAY_5            -0.266200
# PAY_6            -0.291100
# BILL_AMT1     51223.330900
# BILL_AMT2     49179.075167
# BILL_AMT3     47013.154800
# BILL_AMT4     43262.948967
# BILL_AMT5     40311.400967
# BILL_AMT6     38871.760400
# PAY_AMT1       5663.580500
# PAY_AMT2       5921.163500
# PAY_AMT3       5225.681500
# PAY_AMT4       4826.076867
# PAY_AMT5       4799.387633
# PAY_AMT6       5215.502567
# dtype: float64

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %% [markdown]
# ## Exploratory

# %%
corr = new_data.corr()
plt.figure(figsize=(18,15))
sns.heatmap(corr, vmin = -1, vmax = 1, annot = True)
plt.title('correlation')
plt.show()

# %%
{column : len(X[column].unique()) for column in X.columns}
# Out:
# {'LIMIT_BAL': 81,
#  'SEX': 2,
#  'EDUCATION': 7,
#  'MARRIAGE': 4,
#  'AGE': 56,
#  'PAY_0': 11,
#  'PAY_2': 11,
#  'PAY_3': 11,
#  'PAY_4': 11,
#  'PAY_5': 10,
#  'PAY_6': 10,
#  'BILL_AMT1': 22723,
#  'BILL_AMT2': 22346,
#  'BILL_AMT3': 22026,
#  'BILL_AMT4': 21548,
#  'BILL_AMT5': 21010,
#  'BILL_AMT6': 20604,
#  'PAY_AMT1': 7943,
#  'PAY_AMT2': 7899,
#  'PAY_AMT3': 7518,
#  'PAY_AMT4': 6937,
#  'PAY_AMT5': 6897,
#  'PAY_AMT6': 6939}

# %%
plt.figure()
plt.subplot(1, 3, 1)
sex = new_data['SEX'].value_counts().plot.bar(figsize=(16,4), title='Sex')
plt.bar_label(sex.containers[0])

plt.subplot(1, 3, 2)
education = new_data['EDUCATION'].value_counts().plot.bar(figsize=(16,4), title='Education')
plt.bar_label(education.containers[0])

plt.subplot(1, 3, 3)
marriage = new_data['MARRIAGE'].value_counts().plot.bar(figsize=(16,4), title='Marriage')
plt.bar_label(marriage.containers[0])
# Out:
# [Text(0, 0, '15964'), Text(0, 0, '13659'), Text(0, 0, '323'), Text(0, 0, '54')]

# %%
new_data.groupby(['EDUCATION'])['MARRIAGE'].value_counts()
# Out:
# EDUCATION  MARRIAGE
# 0          2             10
#            1              4
# 1          2           6809
#            1           3722
#            3             50
#            0              4
# 2          2           7020
#            1           6842
#            3            162
#            0              6
# 3          1           2861
#            2           1909
#            3            103
#            0             44
# 4          2             68
#            1             52
#            3              3
# 5          1            150
#            2            127
#            3              3
# 6          1             28
#            2             21
#            3              2
# Name: MARRIAGE, dtype: int64

# %%
plt.subplots(figsize=(20,5))
plt.subplot(121)
sns.distplot(new_data.LIMIT_BAL)

plt.subplot(122)
sns.distplot(new_data.AGE)

plt.show()
# Out:
# <ipython-input-17-cf7ae540f8a6>:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121)
# <ipython-input-17-cf7ae540f8a6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data.LIMIT_BAL)
# <ipython-input-17-cf7ae540f8a6>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %%
cat_columns = ['SEX', 'EDUCATION', 'MARRIAGE', 'PAY_0','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# %%
fig, axis = plt.subplots(3,3,figsize=(15,15))

for i, ax in enumerate(axis.flatten()):
    if i < len(cat_columns):
        sns.countplot(data=new_data, x=cat_columns[i], ax=ax, palette='Set1', hue='default.payment.next.month')
        ax.set_title(f'Countplot of {cat_columns[i]}')

plt.tight_layout()
plt.show()

# %%
num_columns = ['AGE', 'LIMIT_BAL', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
fig, axis = plt.subplots(1,2,figsize=(8,4))

for i, ax in enumerate(axis.flatten()):
    if i < len(num_columns[:2]):
        sns.histplot(data= new_data, x=num_columns[:2][i], ax=ax, kde=True)
        ax.set_title(f'Boxplot of {num_columns[i]}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Modeling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
print(X)
# Out:
# [[-1.13672015  0.81016074  0.18582826 ... -0.30806256 -0.31413612
#   -0.29338206]
#  [-0.3659805   0.81016074  0.18582826 ... -0.24422965 -0.31413612
#   -0.18087821]
#  [-0.59720239  0.81016074  0.18582826 ... -0.24422965 -0.24868274
#   -0.01212243]
#  ...
#  [-1.05964618 -1.23432296  0.18582826 ... -0.03996431 -0.18322937
#   -0.11900109]
#  [-0.67427636 -1.23432296  1.45111372 ... -0.18512036  3.15253642
#   -0.19190359]
#  [-0.90549825 -1.23432296  0.18582826 ... -0.24422965 -0.24868274
#   -0.23713013]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 123)

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
lr_model.fit(X_test, y_test)
#ค่า accuracy
print("train score : ", lr_model.score(X_train, y_train))
print("test score : ", lr_model.score(X_test, y_test))
# Out:
# train score :  0.8073809523809524
# test score :  0.8115555555555556

# %%
from sklearn.metrics import accuracy_score
y_pred = lr_model.predict(X_test)
#y_pred
print("Accuracy of logistic regression on test set : ", accuracy_score(y_test, y_pred) * 100)
# Out:
# Accuracy of logistic regression on test set :  81.15555555555557

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      7052
#            1       0.70      0.23      0.35      1948
#
#     accuracy                           0.81      9000
#    macro avg       0.76      0.60      0.62      9000
# weighted avg       0.79      0.81      0.77      9000
#
# [[6857  195]
#  [1501  447]]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
knn_model.fit(X_test, y_test)
# Out:
# KNeighborsClassifier()

# %%
#ค่า Accuracy
print("train score : ", knn_model.score(X_train, y_train))
print("test score : ", knn_model.score(X_test, y_test))
# Out:
# train score :  0.7876190476190477
# test score :  0.8402222222222222

# %%
from sklearn.metrics import accuracy_score
y_pred_knn = knn_model.predict(X_test)
print("Accuracy of knn on test set : ", accuracy_score(y_test, y_pred_knn) * 100)
# Out:
# Accuracy of knn on test set :  84.02222222222223

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred_knn))
print(confusion_matrix(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      7052
#            1       0.70      0.45      0.55      1948
#
#     accuracy                           0.84      9000
#    macro avg       0.78      0.70      0.73      9000
# weighted avg       0.83      0.84      0.83      9000
#
# [[6684  368]
#  [1070  878]]
